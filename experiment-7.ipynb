# %%
# Experiment 7: Build Tools (Simple Version)
# This program simulates a small build/run process

print("Build Started...")
print("Running Program...")
print("Build Successful!")
# Out:
# Build Started...
# Running Program...
# Build Successful!

# %%
def add(a, b):
    return a + b

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("Result:", add(num1, num2))
# Out:
# Result: 7

# %%
# Explanation:
# This notebook demonstrates a simple build process.
# Code is written, executed, and verified successfully.
# This simulates how build tools automate execution.
