# %%
# Fixed program

num = int(input("Enter a number: "))

# Correct logic
if num % 2 == 0:
    print("Number is even")
else:
    print("Number is odd")

# Fixed runtime error
result = 10 / 2
print("Result:", result)
# Out:
# Number is odd
# Result: 5.0
